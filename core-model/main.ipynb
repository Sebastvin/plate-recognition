# %%
# %cd C:
# Out:
# C:\

# %%
from yolov5 import train, val, detect, export
import yolov5
import matplotlib.pyplot as plt
from IPython.display import display
import numpy as np
# %cd D:\Projects\plate-recognition\libraries\scikit-learn
# Out:
# D:\Projects\plate-recognition\libraries\scikit-learn

# %%
img = "auto.jpg"
weights = "best_model.pt"

# %%
model = yolov5.load(weights)
# Out:
# YOLOv5  2023-5-22 Python-3.11.3 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 379 layers, 35275944 parameters, 0 gradients, 49.3 GFLOPs
# Adding AutoShape...

# %%
# Set the confidence threshold value
model.conf = 0.45

# inference with larger input size
results = model(img, size=1200)

# inference with test time augmentation
results = model(img, augment=True)

# %%
# parse results
predictions = results.pred[0]
boxes = predictions[:, :4] # x1, y1, x2, y2
scores = predictions[:, 4]
categories = predictions[:, 5]

# show detection bounding boxes on image
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1536x864>
